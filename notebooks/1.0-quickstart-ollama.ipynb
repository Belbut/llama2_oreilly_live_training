# %% [markdown]
# # Getting Started with Local LLMs using Ollama
#
# This notebook demonstrates how to run local language models using [Ollama](https://ollama.com/), an easy-to-use tool for running LLMs locally on your machine.
#
# ## Prerequisites
#
# 1. Install Ollama from https://ollama.com/download
# 2. Pull a model (e.g., `ollama pull gemma4`)
# 3. (alternative see screenshot)
# <!-- ![](2026-02-03-16-01-24.png) -->
# 1. Ensure Ollama is running in the background
#
# ## What You'll Learn
#
# - How to interact with local LLMs using the Ollama Python library
# - Making basic API calls to local models
# - Listing available models
# - Creating reusable helper functions for LLM interactions

# %%
# !pip install ollama

# %% [markdown]
# ## Step 1: Install the Ollama Python Library

# %%
import ollama

response = ollama.chat(model="gemma4", 
                       messages=[
                         {
                           "role": "user",
                           "content": "Say hello to my students for the course: 'Getting Started with Local LLMs'. One single sentence."
                         }
                       ]
                       )

print(response['message']['content'])
# Out:
# Here are a few options, depending on whether you want the tone to be encouraging, professional, or highly enthusiastic.
#
# **🚀 Enthusiastic & Engaging:**
# > Welcome to 'Getting Started with Local LLMs,' where we are going to unlock the amazing power of running powerful AI models entirely on your own machine!
#
# **💡 Professional & Confident:**
# > I'm excited to guide you through 'Getting Started with Local LLMs,' a course that will equip you with the skills to run advanced AI models offline, giving you unprecedented control and privacy.
#
# **🌟 Simple & Direct:**
# > Welcome aboard! Let's begin our journey into 'Getting Started with Local LLMs' and learn how to bring the cutting edge of AI right to your local hardware.

# %% [markdown]
# ## Step 2: Your First Chat with a Local LLM
#
# The `ollama.chat()` function sends messages to a local model and returns the response.

# %%
# Try with a different model - you can easily switch between models
import ollama

response = ollama.chat(model='gemma4', messages=[
  {
    'role': 'user',
    'content': 'Say hello to my students for the course: "Getting Started with Local LLMs". One single sentence.',
  },
])
print(response['message']['content'])
# Out:
# ---------------------------------------------------------------------------
# ResponseError                             Traceback (most recent call last)
# Cell In[4], line 4
#       1 # Try with a different model - you can easily switch between models
#       2 import ollama
#       3
# ----> 4 response = ollama.chat(model='gemma3n', messages=[
#       5   {
#       6     'role': 'user',
#       7     'content': 'Say hello to my students for the course: "Getting Started with Llama 3". One single sentence.',
#
# File ~/Work/clients/collab_lucas/oreilly_courses/llama2_oreilly_live_training/oreilly-llama3/lib/python3.14/site-packages/ollama/_client.py:387, in Client.chat(self, model, messages, tools, stream, think, logprobs, top_logprobs, format, options, keep_alive)
#     340 def chat(
#     341   self,
#     342   model: str = '',
#    (...)    352   keep_alive: Optional[Union[float, str]] = None,
#     353 ) -> Union[ChatResponse, Iterator[ChatResponse]]:
#     354   """
#     355   Create a chat response using the requested model.
#     356
#    (...)    385   Returns `ChatResponse` if `stream` is `False`, otherwise returns a `ChatResponse` generator.
#     386   """
# --> 387   return self._request(
#     388     ChatResponse,
#     389     'POST',
#     390     '/api/chat',
#     391     json=ChatRequest(
#     392       model=model,
#     393       messages=list(_copy_messages(messages)),
#     394       tools=list(_copy_tools(tools)),
#     395       stream=stream,
#     396       think=think,
#     397       logprobs=logprobs,
#     398       top_logprobs=top_logprobs,
#     399       format=format,
#     400       options=options,
#     401       keep_alive=keep_alive,
#     402     ).model_dump(exclude_none=True),
#     403     stream=stream,
#     404   )
#
# File ~/Work/clients/collab_lucas/oreilly_courses/llama2_oreilly_live_training/oreilly-llama3/lib/python3.14/site-packages/ollama/_client.py:199, in Client._request(self, cls, stream, *args, **kwargs)
#     195         yield cls(**part)
#     197   return inner()
# --> 199 return cls(**self._request_raw(*args, **kwargs).json())
#
# File ~/Work/clients/collab_lucas/oreilly_courses/llama2_oreilly_live_training/oreilly-llama3/lib/python3.14/site-packages/ollama/_client.py:143, in Client._request_raw(self, *args, **kwargs)
#     141   return r
#     142 except httpx.HTTPStatusError as e:
# --> 143   raise ResponseError(e.response.text, e.response.status_code) from None
#     144 except httpx.ConnectError:
#     145   raise ConnectionError(CONNECTION_ERROR_MESSAGE) from None
#
# ResponseError: model 'gemma3n' not found (status code: 404)

# %%
# !ollama list
# Out:
# NAME                     ID              SIZE      MODIFIED
# llama3.2:latest          a80c4f17acd5    2.0 GB    19 seconds ago
# gemma3:latest            a2af6cc3eb7f    3.3 GB    2 months ago
# gemma3:1b                8648f39daa8f    815 MB    6 months ago
# gemma3n:latest           15cb39fd9394    7.5 GB    7 months ago
# gemma3:27b               a418f5838eaf    17 GB     9 months ago
# dolphin-llama3:latest    613f068e29f8    4.7 GB    16 months ago

# %% [markdown]
# ## Step 3: List Available Models
#
# You can list all models available locally using the `ollama list` command.

# %%
def chat_with_local_llm(model_name: str, prompt: str) -> str:
    """
    Send a prompt to a local LLM via Ollama and return the response.
    
    Args:
        model_name: The name of the model to use (e.g., 'gemma4')
        prompt: The user prompt to send to the model
    
    Returns:
        The model's response as a string
    """
    response = ollama.chat(
        model=model_name,  # Use the passed model_name parameter
        messages=[
            {
                'role': 'user',
                'content': prompt,
            },
        ]
    )
    output = response['message']['content']
    print(output)
    
    return output

# Example usage
chat_with_local_llm(
    "gemma4", 
    'Write a one sentence prediction of the impact AI/LLMs will have on the world in 2026.'
)
# Out:
# By 2026, Large Language Models (LLMs) are expected to revolutionize various industries such as customer service, content creation, and education by providing fast, accurate, and personalized assistance that augments human capabilities, but also raises concerns about job displacement, data privacy, and the blurring of lines between human creativity and machine-generated output.
# 'By 2026, Large Language Models (LLMs) are expected to revolutionize various industries such as customer service, content creation, and education by providing fast, accurate, and personalized assistance that augments human capabilities, but also raises concerns about job displacement, data privacy, and the blurring of lines between human creativity and machine-generated output.'

# %% [markdown]
# ## Summary
#
# In this notebook, you learned how to:
#
# 1. **Install** the Ollama Python library
# 2. **Chat** with local LLMs using `ollama.chat()`
# 3. **List** available models with `ollama list`
# 4. **Create** a reusable helper function for LLM interactions
#
# ## Next Steps
#
# - Explore more models: `ollama pull gemma4:26b` (8 GB VRAM) or `gemma4:e4b` (CPU-only)
# - Check out structured outputs in notebook `3.1-llama31-structured-outputs.ipynb`
# - Learn about RAG with local LLMs in notebook `2.0-introduction-to-rag.ipynb`
#
# For more information, visit the [Ollama Documentation](https://ollama.com/)

# %% [markdown]
# ## Step 4: Create a Reusable Helper Function
#
# Let's create a reusable function for chatting with local models.
